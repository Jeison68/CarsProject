# %% [markdown]
# Cargar Librerias

# %%
import timeit
import numpy as numpy
import pandas as pandas
import matplotlib as plt
from sklearn import linear_model

# %%
df = pandas.read_csv('new_cars.csv')
df.head()
# Out:
#   manufacturer_name model_name transmission   color  odometer_value  \
# 0            Subaru    Outback    automatic  silver          190000
# 1            Subaru    Outback    automatic    blue          290000
# 2            Subaru   Forester    automatic     red          402000
# 3            Subaru    Impreza   mechanical    blue           10000
# 4            Subaru     Legacy    automatic   black          280000
#
#    year_produced engine_fuel engine_type  engine_capacity  body_type  \
# 0           2010    gasoline    gasoline              2.5  universal
# 1           2002    gasoline    gasoline              3.0  universal
# 2           2001    gasoline    gasoline              2.5        suv
# 3           1999    gasoline    gasoline              3.0      sedan
# 4           2001    gasoline    gasoline              2.5  universal
#
#    price_usd  up_counter
# 0   10900.00          13
# 1    5000.00          54
# 2    2800.00          72
# 3    9999.00          42
# 4    2134.11           7

# %%
X, y = df[['odometer_value']], df['price_usd']
raw_model = linear_model.LinearRegression()
raw_model.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# Procesamiento datos Categoricos

# %%
import sklearn.preprocessing as preprocessing
encoder = preprocessing.OneHotEncoder(handle_unknown='ignore')

# %%
encoder.fit(df[['engine_type']].values)
# Out:
# OneHotEncoder(handle_unknown='ignore')

# %%
encoder.transform([['gasoline'],['diesel'],['aceite']]).toarray()
# Out:
# array([[0., 1.],
#        [1., 0.],
#        [0., 0.]])

# %%
import seaborn as sns

# %%
sns.pairplot(df, hue = 'engine_type')
